# %% [markdown]
# # Model Selection

# %% [markdown]
# This is a notebook that I will use to better understand how different models (running loacally or as remote API) can work and how much will they cost.
# <br>
# I will hereby prepare:
# 1. A list of of candidate models (mostly from HuggingFace) that can run locally
# 2. A list of of candidate models that can be used through API clients (e.g. OpenAI, Claude, Mistral, etc.)
# 3. Performance estimations code, based on prompts and possible expected outputs.
# 4. Costs estimation costs, based on parametric, representative pro-session queries and then tokens usage.
